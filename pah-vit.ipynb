jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_607.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_174.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_169.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_109.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_159.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_301.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_167.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_554.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_212.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_390.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_472.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_483.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_588.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_171.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_510.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_064.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_365.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_527.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_312.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_533.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_163.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_328.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_636.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_241.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_594.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_031.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_206.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_550.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_523.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_272.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_633.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_528.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_491.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_052.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_425.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_185.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_320.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_383.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_626.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_231.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_111.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_408.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_269.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_611.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_337.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_463.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_506.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_292.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_438.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_139.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_421.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_095.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_467.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_605.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_652.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_487.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_055.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_597.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_009.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_511.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_567.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_213.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_447.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_177.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_217.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_534.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_192.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_440.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_005.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_220.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_084.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_286.jpg
# /kaggle/input/echopah/EchoDatasetPAH/PAH/PAH_500.jpg

# %%
import os 
import matplotlib.pyplot as plt
import cv2

dataset_path = "/kaggle/input/echopah/EchoDatasetPAH/PAH"
images_files = sorted(os.listdir(dataset_path))
print(f'Number of files in the folder:{len(images_files)}')
images_files = images_files[:5]
plt.figure(figsize=(15,5))

for i, img_file in enumerate(images_files):
    img_path = os.path.join(dataset_path, img_file)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    plt.subplot(1,5,i+1)
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.title(f'PAH Image{i+1}')

plt.show()
# Out:
# Number of files in the folder:659

# %%
import os 
import matplotlib.pyplot as plt
import cv2

dataset_path = "/kaggle/input/echopah/EchoDatasetPAH/NonPAH"
images_files = sorted(os.listdir(dataset_path))
print(f'Number of files in the folder:{len(images_files)}')
images_files = images_files[:5]
plt.figure(figsize=(15,5))

for i, img_file in enumerate(images_files):
    img_path = os.path.join(dataset_path, img_file)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    plt.subplot(1,5,i+1)
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.title(f'NonPAH Image{i+1}')

plt.show()
# Out:
# Number of files in the folder:473

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

pah_path = "/kaggle/input/echopah/EchoDatasetPAH/PAH"
non_pah_path = "/kaggle/input/echopah/EchoDatasetPAH/NonPAH"
output_path = "/kaggle/working/dataset"

# %%
train_pah_dir = os.path.join(output_path, "train/PAH")
train_non_pah_dir = os.path.join(output_path, "train/NonPAH")
test_pah_dir = os.path.join(output_path, "test/PAH")
test_non_pah_dir = os.path.join(output_path, "test/NonPAH")

# %%
os.makedirs(train_pah_dir, exist_ok=True)
os.makedirs(train_non_pah_dir, exist_ok=True)
os.makedirs(test_pah_dir, exist_ok=True)
os.makedirs(test_non_pah_dir, exist_ok=True)

# %%
pah_images = sorted(os.listdir(pah_path))
non_pah_images= sorted(os.listdir(non_pah_path))

# %%
pah_train, pah_test = train_test_split(pah_images, test_size=0.2, random_state=42)
non_pah_train, non_pah_test = train_test_split(non_pah_images,test_size=0.2, random_state=42)

# %%
for file in pah_train:
    shutil.copy(os.path.join(pah_path,file), os.path.join(train_pah_dir, file))
for file in pah_test:
    shutil.copy(os.path.join(pah_path,file),os.path.join(test_pah_dir, file))
for file in non_pah_train:
    shutil.copy(os.path.join(non_pah_path,file),os.path.join(train_non_pah_dir,file))
for file in non_pah_test:
    shutil.copy(os.path.join(non_pah_path,file),os.path.join(test_non_pah_dir,file))

# %%
datacheck = ["/kaggle/working/dataset/test/NonPAH", "/kaggle/working/dataset/test/PAH"]
im_file1 = sorted(os.listdir(datacheck[0]))
im_file2 = sorted(os.listdir(datacheck[1]))
len(im_file1),len(im_file2)
# Out:
# (95, 132)

# %%
import os
import torch
import torch.nn as nn
from transformers import ViTModel, ViTConfig
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from tqdm import tqdm

# Define dataset directory paths
DATASET_PATH = "/kaggle/working/dataset"
TRAIN_DIR = os.path.join(DATASET_PATH, "train")
TEST_DIR = os.path.join(DATASET_PATH, "test")

# Define transformations for image preprocessing
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize for ViT
    transforms.Grayscale(3),  # Convert grayscale to RGB
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.1, 0.1, 0.1], std=[0.1, 0.1, 0.1])
])

# Load dataset using ImageFolder
train_dataset = datasets.ImageFolder(root=TRAIN_DIR, transform=transform)
test_dataset = datasets.ImageFolder(root=TEST_DIR, transform=transform)

# Create DataLoaders
BATCH_SIZE = 32
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Check class indices (ASD -> 0, NonASD -> 1)
print(train_dataset.class_to_idx)  # Example output: {'ASD': 0, 'NonASD': 1}
# Out:
# {'NonPAH': 0, 'PAH': 1}

# %%
class ViTClassifier(nn.Module):
    def __init__(self, num_classes=2):
        super(ViTClassifier, self).__init__()
        config = ViTConfig(
            hidden_size=768,
            num_attention_heads=12,
            num_hidden_layers=12,
            intermediate_size=3072,
            image_size=224,
            patch_size=16,
            num_channels=3,  # RGB images
            num_labels=num_classes
        )
        self.vit = ViTModel(config)
        self.classifier = nn.Linear(config.hidden_size, num_classes)

    def forward(self, x):
        x = self.vit(x)['last_hidden_state']
        output = self.classifier(x[:, 0, :])  # Use CLS token embedding
        return output

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize model, optimizer, and loss function
model = ViTClassifier().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=2e-5)
criterion = nn.CrossEntropyLoss()

# Training function
def train(model, dataloader, optimizer, criterion, epochs=5):
    model.train()
    for epoch in range(epochs):
        loop = tqdm(dataloader, desc=f"Epoch {epoch+1}/{epochs}")
        total_loss = 0
        for images, labels in loop:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            loop.set_postfix(loss=total_loss / len(dataloader))
    print("Training complete.")

# Train the model
train(model, train_loader, optimizer, criterion)
# Out:
# Epoch 1/5: 100%|██████████| 29/29 [00:21<00:00,  1.32it/s, loss=0.959]
# Epoch 2/5: 100%|██████████| 29/29 [00:21<00:00,  1.33it/s, loss=0.688]
# Epoch 3/5: 100%|██████████| 29/29 [00:21<00:00,  1.32it/s, loss=0.681]
# Epoch 4/5: 100%|██████████| 29/29 [00:21<00:00,  1.32it/s, loss=0.677]
# Epoch 5/5: 100%|██████████| 29/29 [00:22<00:00,  1.32it/s, loss=0.7]
# Training complete.

# %%
def evaluate(model, dataloader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            predictions = torch.argmax(outputs, dim=1)
            correct += (predictions == labels).sum().item()
            total += labels.size(0)
    print(f"Test Accuracy: {100 * correct / total:.2f}%")

# Evaluate on test set
evaluate(model, test_loader)
# Out:
# Test Accuracy: 58.15%

# %%
import os
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from transformers import ViTForImageClassification

# Define dataset path
DATASET_PATH = "/kaggle/working/dataset"
TRAIN_DIR = os.path.join(DATASET_PATH, "train")
TEST_DIR = os.path.join(DATASET_PATH, "test")

# Define image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize for ViT
    transforms.Grayscale(3),  # Convert grayscale to RGB if needed
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.1, 0.1, 0.1], std=[0.1, 0.1, 0.1])  # Normalize
])

# Load datasets
train_dataset = datasets.ImageFolder(root=TRAIN_DIR, transform=transform)
test_dataset = datasets.ImageFolder(root=TEST_DIR, transform=transform)

# Create DataLoaders
BATCH_SIZE = 32
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Check class indices (e.g., {'ASD': 0, 'NonASD': 1})
print(train_dataset.class_to_idx)
# Out:
# {'NonPAH': 0, 'PAH': 1}

# %%
from transformers import ViTFeatureExtractor, ViTForImageClassification

# Load pretrained ViT model
model_name = "google/vit-base-patch16-224-in21k"  # Pretrained on ImageNet-21k
model = ViTForImageClassification.from_pretrained(model_name, num_labels=2)

# Set device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ViTForImageClassification(
#   (vit): ViTModel(
#     (embeddings): ViTEmbeddings(
#       (patch_embeddings): ViTPatchEmbeddings(
#         (projection): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ViTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ViTLayer(
#           (attention): ViTSdpaAttention(
#             (attention): ViTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
import torch.optim as optim
from tqdm import tqdm

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# Training function
def train(model, dataloader, optimizer, criterion, epochs=10):
    model.train()
    for epoch in range(epochs):
        loop = tqdm(dataloader, desc=f"Epoch {epoch+1}/{epochs}")
        total_loss = 0
        for images, labels in loop:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images).logits  # Get logits
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            loop.set_postfix(loss=total_loss / len(dataloader))
    print("Training complete.")

# Train model
train(model, train_loader, optimizer, criterion)
# Out:
# Epoch 1/10: 100%|██████████| 29/29 [00:21<00:00,  1.33it/s, loss=0.231]
# Epoch 2/10: 100%|██████████| 29/29 [00:22<00:00,  1.31it/s, loss=0.0179]
# Epoch 3/10: 100%|██████████| 29/29 [00:21<00:00,  1.32it/s, loss=0.00917]
# Epoch 4/10: 100%|██████████| 29/29 [00:22<00:00,  1.31it/s, loss=0.00711]
# Epoch 5/10: 100%|██████████| 29/29 [00:21<00:00,  1.32it/s, loss=0.00587]
# Epoch 6/10: 100%|██████████| 29/29 [00:22<00:00,  1.31it/s, loss=0.005]
# Epoch 7/10: 100%|██████████| 29/29 [00:22<00:00,  1.31it/s, loss=0.00432]
# Epoch 8/10: 100%|██████████| 29/29 [00:21<00:00,  1.32it/s, loss=0.00379]
# Epoch 9/10: 100%|██████████| 29/29 [00:22<00:00,  1.32it/s, loss=0.00336]
# Epoch 10/10: 100%|██████████| 29/29 [00:22<00:00,  1.31it/s, loss=0.00299]
# Training complete.

# %%
def evaluate(model, dataloader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images).logits
            predictions = torch.argmax(outputs, dim=1)
            correct += (predictions == labels).sum().item()
            total += labels.size(0)
    print(f"Test Accuracy: {100 * correct / total:.2f}%")

# Evaluate model
evaluate(model, test_loader)
# Out:
# Test Accuracy: 97.36%
